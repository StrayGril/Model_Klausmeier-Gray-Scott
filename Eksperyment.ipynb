# %%
import numpy as np

# %% [markdown]
# # Szybka teoria
# Zakres parametrów:
#
# * $a \in (0, \infty)$
# * $m \in (0, \frac{a}{2})$
# * $d_1 \in (d_2, \infty)$
# * $d_2 \in (0, \infty)$
#
# Założenia, z których korzystamy:
#
# - $a^2 - 4m^2 \geq 0$ z $\Delta$ stanu stacjonarnego
# - $d_1 \leq d_2$
#
# # Test
# W teście skorzystamy z przewidywania istnienia Turinga, więc musimy jedynie dokładnie przetestować $d_1$ i $d_2$

# %% [markdown]
# ## Badanie parametru $d_1$
# stałe $d_2 = $ i $d_1 \in [0,1]$

# %% [markdown]
# ## Badanie parametru $d_2$
# stałe $d_1 = 0.1$ i $d_2 \in [1,100]$

# %%
d1 = 0.1
d2_vals = np.arange(1, 100, 1)
