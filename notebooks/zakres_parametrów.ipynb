# %%
import sys
import os

# Dodanie katalogu głównego repo do ścieżki
sys.path.append(os.path.abspath(".."))

import numpy as np
import matplotlib.pyplot as plt
#from pipeline.turing_instability import turing_analysis
#from pipeline.model_core import homogeneous_state
from pipeline.parametres_search import scan_turing_am, plot_lambda_map, plot_turing_regions

# %%
# zakres m i a
m_values = np.arange(0.1, 1.51, 0.1)
a_values = np.linspace(0.0, 6.0, 250)

# %%
# Test dla dyfuzji:
d1 = 20
d2 = 0.2



results_20_02 = scan_turing_am(d1, d2, m_values=m_values, a_values=a_values, k_min = 0, k_max=20, n_k=4000)
plot_lambda_map(results_20_02)
plot_turing_regions(results_20_02)
