# %% [markdown]
# ## **Analiza niestabilności Turinga**

# %%
import sys
import os

# Dodanie katalogu głównego repo do ścieżki
sys.path.append(os.path.abspath(".."))

# %%
from pipeline.turing import turing_analysis, plot_dispersion

# Parametry do ustawienia
a = 4
m = 1.2
d1 = 1.5
d2 = 0.02

# Wykres i wynik
res = turing_analysis(a, m, d1, d2, k_min = 2, k_max = 8)
plot_dispersion(
    res["k"],
    res["lambda"],
    res["band"],
    res["a"],
    res["m"],
    res["d1"],
    res["d2"]
)
