# %% [markdown]
# ## Analiza błędu kroku czasowego $h_t$

# %%
import sys
import os
# Dodanie katalogu głównego repo do ścieżki
sys.path.append(os.path.abspath(".."))

import numpy as np
import matplotlib.pyplot as plt
from pipeline.step_analysis import test_ht

# %% [markdown]
# # Aktualnie używane do generowania (w Eksperyment itd.)

# %%
Lx = 60
Ly = Lx
Nx = 100
Ny = Nx

m = 0.45
a = 2 #przykładowe bo mamy 5 różnych dobieranych przez funkcję
d1 = 100 # domyślna wartość gdy testujemu d2
d2 = 0.02 # domyślna wartość gdy testujemu d1

T = 10000 # maksymalny czas symulacji (u nas może się skończyć wcześniej)

nasze_kroki = np.arange(0.01,1.5,0.01)
u_nasze, v_nasze = test_ht(T=T, kroki=nasze_kroki, a=a, m=m, d1=d1, d2=d2, Lx=Lx, Ly=Ly, Nx=Nx, Ny=Ny)
# Out:
#   0%|                                                                                                                                                      | 0/149 [11:47<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      11 T = 10000 # maksymalny czas symulacji (u nas może się skończyć wcześniej)
#      13 nasze_kroki = np.arange(0.01,1.5,0.01)
# ---> 14 u_nasze, v_nasze = test_ht(T=T, kroki=nasze_kroki, a=a, m=m, d1=d1, d2=d2, Lx=Lx, Ly=Ly, Nx=Nx, Ny=Ny)
#
# File ~\PycharmProjects\ZPS\pipeline\step_analysis.py:79, in test_ht(T, kroki, a, m, d1, d2, Lx, Ly, Nx, Ny)
#      77 u_1, v_1 = step_reaction_diffusion(u_1, v_1, a, m, ht, lu_Au1, lu_Av1, brzeg)
#      78 for i in range(2): # dla ht/2 dwa obroty pętli
# ---> 79     u_2, v_2 = step_reaction_diffusion(u_2, v_2, a, m, ht/2, lu_Au2, lu_Av2, brzeg)
# ...

# %% [markdown]
# # poprzednie poniżej

# %%
# dla argumentów około z bifurkacji

nasze_kroki_geste = np.arange(0.005,2.5,0.005)
u,v = test_ht(100,nasze_kroki_geste,1.9,0.8,0.04,0.0004, 10, 10, 50,50)
#print(u)
#print(v)
plt.show()

# %%
plt.plot(nasze_kroki, np.array(u), label=f"woda", c="blue")
plt.plot(nasze_kroki, np.array(v), label="biomasa", c="green")

plt.title(f"Wykres błędu podwojonego kroku czasowego dla T=100")
plt.xlabel("$h_t$")
plt.ylabel("log(MAE)")
#plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()

# %%
plt.plot(nasze_kroki, np.array(u), label=f"woda", c="blue")
plt.plot(nasze_kroki, np.array(v), label="biomasa", c="green")

plt.title(f"Wykres błędu podwojonego kroku czasowego dla T=100")
plt.xlabel("$h_t$")
plt.ylabel("log(MAE)")
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()

# %%
# dla argumentów około z bifurkacji - mniej krokow
nasze_kroki = np.arange(0.01,2.5,0.01)
u,v = test_ht(100,nasze_kroki,1.9,0.8,0.04,0.0004, 10, 10, 50,50)
#print(u)
#print(v)
plt.show()
# Out:
#   6%|███████▉                                                                                                                                     | 14/250 [00:36<04:13,  1.07s/it]C:\Users\ASUS\PycharmProjects\ZPS\pipeline\core.py:163: RuntimeWarning: overflow encountered in multiply
#   vv = v * v
# C:\Users\ASUS\PycharmProjects\ZPS\pipeline\core.py:164: RuntimeWarning: invalid value encountered in multiply
#   du = a - u - u * vv
# C:\Users\ASUS\PycharmProjects\ZPS\pipeline\core.py:165: RuntimeWarning: invalid value encountered in multiply
#   dv = u * vv - m * v
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 250/250 [01:12<00:00,  3.46it/s]

# %%
# dla argumentow z Eksperyment
nasze_kroki = np.arange(0.01,2.5,0.01)
u,v = test_ht(T=100, kroki=nasze_kroki, a=1.06, m=0.5, d1=100, d2=0.02, Lx=40, Ly=40, Nx=100, Ny=100)
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 250/250 [07:28<00:00,  1.79s/it]

# %%
u_klaus, v_klaus = test_ht(T=100, kroki=nasze_kroki, a=0.045, m=0.045, d1=20, d2=0.02, Lx=10, Ly=10, Nx=50, Ny=50)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 250/250 [01:12<00:00,  3.45it/s]

# %%
# dla uzywanej domeny
u_klausDomena, v_klausDomena = test_ht(T=100, kroki=nasze_kroki, a=0.045, m=0.045, d1=20, d2=0.02, Lx=40, Ly=40, Nx=100, Ny=100)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 250/250 [07:26<00:00,  1.79s/it]

# %%
# dla T=10000
nasze_kroki = np.arange(0.01,1.5,0.01)
u_k1k, v_k1k = test_ht(T=1000, kroki=nasze_kroki, a=0.045, m=0.045, d1=20, d2=0.02, Lx=10, Ly=10, Nx=50, Ny=50)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 149/149 [11:13<00:00,  4.52s/it]
